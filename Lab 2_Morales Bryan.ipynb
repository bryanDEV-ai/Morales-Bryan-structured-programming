# %% [markdown]
# <a href="https://colab.research.google.com/github/bryanDEV-ai/Morales-Bryan-structured-programming/blob/main/Lab%202_Morales%20Bryan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
CODE A
"""

def multiply(a, b):
   return a * b
print(multiply(3,4))

# %%
"""
CODE B
"""

counter = 0
for i in range(4):
    counter = counter + 1
print(counter)

# %%
"""
CODE
